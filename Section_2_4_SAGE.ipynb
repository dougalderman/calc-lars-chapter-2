# %%
#35

# %%
def f(x): return (sqrt(x) + 1)/(x^2 + 1)

# %%
def derf(x): return derivative(f(x))

# %%
derf(x)
# Out:
# -2*x*(sqrt(x) + 1)/(x^2 + 1)^2 + 1/2/((x^2 + 1)*sqrt(x))

# %%
p=[]

# %%
p.append(plot(f(x),(x,0.01,5),color='blue',legend_label='f(x)'))

# %%
p.append(plot(derf(x),(x,0.01,5),color='red',legend_label='derivative f(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
derf(x).find_root(0.01, 5)
# Out:
# 0.31407692089113715

# %%
#65

# %%
def f1(x): return sqrt(x^2 + 8*x)

# %%
def derf1(x): return derivative(f1(x))

# %%
derf1(x)
# Out:
# (x + 4)/sqrt(x^2 + 8*x)

# %%
def derivf1(x): return (x + 4)/sqrt(x^2 + 8*x)

# %%
derivf1(1)
# Out:
# 5/3

# %%
p1=[]

# %%
p1.append(plot(f1(x),(x,0.01,3),color='blue',legend_label='f(x)'))

# %%
p1.append(plot(derf1(x),(x,0.01,3),color='red',legend_label='derivative f(x)'))

# %%
sum(p1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#71

# %%
def f2(x): return 26 - (sec(4*x))^3

# %%
def derf2(x): return derivative(f2(x))

# %%
derf2(x)
# Out:
# -12*sec(4*x)^3*tan(4*x)

# %%
def derivf2(x): return -12*sec(4*x)^3*tan(4*x)

# %%
derivf2(0)
# Out:
# 0

# %%
p2=[]

# %%
p2.append(plot(f2(x),(x,-pi/8+0.01,pi/8-0.01),ymin=-25,ymax=25,color='blue',legend_label='f(x)'))

# %%
p2.append(plot(derf2(x),(x,-pi/8+0.01,pi/8-0.01),ymin=-25,ymax=25,color='red',legend_label='derivative f(x)'))

# %%
sum(p2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#75

# %%
def f3(x): return (4*x^3 + 3)^2

# %%
def derf3(x): return derivative(f3(x))

# %%
derf3(x)
# Out:
# 24*(4*x^3 + 3)*x^2

# %%
def derivf3(x): return 24*(4*x^3 + 3)*x^2

# %%
derivf3(-1)
# Out:
# -24

# %%
def tanf3(x): return -24*x - 23

# %%
p3=[]

# %%
p3.append(plot(f3(x),(x,-1.5,-0.5),ymin=0,ymax=20,color='blue',legend_label='f(x)'))

# %%
p3.append(plot(tanf3(x),(x,-1.5,-0.5),ymin=0,ymax=20,color='red',legend_label='tangent line to f(x) at (-1,1)'))

# %%
sum(p3)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#79

# %%
def f4(x): return (tan(x))^2

# %%
def derf4(x): return derivative(f4(x))

# %%
derf4(x)
# Out:
# 2*(tan(x)^2 + 1)*tan(x)

# %%
def derivf4(x): return 2*(tan(x)^2 + 1)*tan(x)

# %%
derivf4(pi/4)
# Out:
# 4

# %%
def tanf4(x): return 4*x - pi + 1

# %%
p4=[]

# %%
p4.append(plot(f4(x),(x,0,pi/2-0.01),ymin=0,ymax=20,color='blue',legend_label='f(x)'))

# %%
p4.append(plot(tanf4(x),(x,0,pi/2-0.01),ymin=0,ymax=20,color='red',legend_label='tangent line to f(x) at (pi/4, 1)'))

# %%
sum(p4)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#81

# %%
def f5(x): return sqrt(25 - x^2)

# %%
def derf5(x): return derivative(f5(x))

# %%
derf5(x)
# Out:
# -x/sqrt(-x^2 + 25)

# %%
def derivf5(x): return -x/sqrt(-x^2 + 25)

# %%
derivf5(3)
# Out:
# -3/4

# %%
def tanf5(x): return (-3/4)*x + 25/4

# %%
p5=[]

# %%
p5.append(plot(f5(x),(x,-5,5),color='blue',legend_label='f(x)'))

# %%
p5.append(plot(tanf5(x),(x,-5,5),color='red',legend_label='tangent line to f(x) at (3,4)'))

# %%
sum(p5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#91

# %%
def f6(x): return (1/9)*(3*x + 1)^3

# %%
def der2f6(x): return derivative(f6(x), 2)

# %%
der2f6(x)
# Out:
# 18*x + 6

# %%
def deriv2f6(x): return 18*x + 6

# %%
deriv2f6(1)
# Out:
# 24

# %%
p6=[]

# %%
p6.append(plot(f6(x),(x,-1,3),ymin=-30,ymax=30,color='blue',legend_label='f(x)'))

# %%
p6.append(plot(der2f6(x),(x,-1,3),ymin=-30,ymax=30,color='red',legend_label='second derivative of f(x)'))

# %%
sum(p6)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
#93

# %%
def f7(x): return cos(x^2)

# %%
def der2f7(x): return derivative(f7(x), 2)

# %%
der2f7(x)
# Out:
# -4*x^2*cos(x^2) - 2*sin(x^2)

# %%
def deriv2f7(x): return -4*x^2*cos(x^2) - 2*sin(x^2)

# %%
deriv2f7(0)
# Out:
# 0

# %%
p7=[]

# %%
p7.append(plot(f7(x),(x,-pi,pi),ymin=-20,ymax=20,color='blue',legend_label='f(x)'))

# %%
p7.append(plot(der2f7(x),(x,-pi,pi),ymin=-20,ymax=20,color='red',legend_label='second derivative of f(x)'))

# %%
sum(p7)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#109

# %%
t=var('t')

# %%
def T(t): return 21.414 + 58.287*sin((pi/12)*t - pi/12)

# %%
plot(T(t),(t,1,12),color='blue',legend_label='T(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def derT(t): return derivative(T(t))

# %%
derT(t)
# Out:
# 4.85725000000000*pi*cos(-1/12*pi + 1/12*pi*t)

# %%
plot(derT(t),(t,1,12),color='blue',legend_label='Derivative of T(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#123

# %%
def f8(x): return tan(x)

# %%
def derf8(x): return derivative(f8(x))

# %%
derf8(x)
# Out:
# tan(x)^2 + 1

# %%
def derivf8(x): return tan(x)^2 + 1

# %%
derivf8(pi/4)
# Out:
# 2

# %%
def der2f8(x): return derivative(f8(x), 2)

# %%
der2f8(x)
# Out:
# 2*(tan(x)^2 + 1)*tan(x)

# %%
def deriv2f8(x): return 2*(tan(x)^2 + 1)*tan(x)

# %%
deriv2f8(pi/4)
# Out:
# 4

# %%
def P1f8(x): return 2*x + (1 - pi/2)

# %%
def P2f8(x): return 2*x^2 + (2 - pi)*x + (1 - pi/2 + pi^2/8)

# %%
p8=[]

# %%
p8.append(plot(f8(x),(x,pi/8,3*pi/8),color='blue',legend_label='f(x)'))

# %%
p8.append(plot(P1f8(x),(x,pi/8,3*pi/8),color='red',legend_label='P1(x)'))

# %%
p8.append(plot(P2f8(x),(x,pi/8,3*pi/8),color='green',legend_label='P2(x)'))

# %%
sum(p8)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
f8(pi/4)
# Out:
# 1

# %%
P1f8(pi/4)
# Out:
# 1

# %%
n(P1f8(pi/4))
# Out:
# 1.00000000000000

# %%
P2f8(pi/4)
# Out:
# -1/2*pi + 1/4*pi^2 - 1/4*pi*(pi - 2) + 1

# %%
n(P2f8(pi/4))
# Out:
# 1.00000000000000
