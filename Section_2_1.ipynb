# %%
#25

# %%
def f(x): return x^2 + 3

# %%
def tan(x): return -2*x + 2

# %%
p=[]

# %%
p.append(plot(f(x),(x,-4,3),color='blue',legend_label='f(x)'))

# %%
p.append(plot(tan(x),(x,-4,3),color='red',legend_label='tangent line at (-1, 4)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def der(x): return derivative(f(x))

# %%
der(x)
# Out:
# 2*x

# %%
def deriv(x): return 2*x

# %%
deriv(-1)
# Out:
# -2

# %%
#31

# %%
def f1(x): return x + 4/x

# %%
def tan1(x): return (3/4)*x - 2

# %%
p1 = []

# %%
p1.append(plot(f1(x),(x,-7,-1),color='blue',legend_label='f1(x)'))

# %%
p1.append(plot(tan1(x),(x,-7,-1),color='red',legend_label='tangent line at (-4,-5)'))

# %%
sum(p1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def der1(x): return derivative(f1(x))

# %%
der1(x)
# Out:
# -4/x^2 + 1

# %%
def deriv1(x): return -4/x^2 + 1

# %%
deriv1(-4)
# Out:
# 3/4

# %%
#59

# %%
def f2(x): return (1/2)*x^2

# %%
plot(f2(x),(x,-2,2),color='blue',legend_label='f2(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def der2(x): return derivative(f2(x))

# %%
der2(x)
# Out:
# x

# %%
def deriv2(x): return x

# %%
deriv2(0)
# Out:
# 0

# %%
deriv2(1/2)
# Out:
# 1/2

# %%
deriv2(1)
# Out:
# 1

# %%
deriv2(2)
# Out:
# 2

# %%
deriv2(-1/2)
# Out:
# -1/2

# %%
deriv2(-1)
# Out:
# -1

# %%
deriv2(-2)
# Out:
# -2

# %%
plot(deriv2(x),(x,-2,2),color='blue',legend_label='Derivative of f2(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#61

# %%
def f3(x): return 2*x - x^2

# %%
def g3(x): return (f3(x + 0.01) - f3(x))/0.01

# %%
p3 = []

# %%
p3.append(plot(f3(x),(x,-2,2),color='blue',legend_label='f3(x)'))

# %%
p3.append(plot(g3(x),(x,-2,2),color='red',legend_label='g3(x)'))

# %%
sum(p3)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#81

# %%
def f4(x): return abs(x - 5)

# %%
plot(f4(x),(x,0,10),color='blue',legend_label='f4(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#91

# %%
m = var('m')

# %%
def d(m): return sqrt(((9*m^2*(m+1)^2) + (3*m+3)^2)/(1+m^2)^2)

# %%
plot(d(m),(m,-5,5),color='blue',legend_label='d(m)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def d1(m): return (3*abs(m+1))/sqrt(m^2+1)

# %%
plot(d1(m),(m,-5,5),color='blue',legend_label='d1(m)')
# Out:
# Graphics object consisting of 1 graphics primitive
