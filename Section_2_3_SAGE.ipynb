# %%
#55

# %%
def g(x): return ((x+1)/(x+2))*(2*x-5)

# %%
plot(g(x),(x,-1.9,5),color='blue',legend_label='g(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def derg(x): return derivative(g(x))

# %%
derg(x)
# Out:
# (2*x - 5)/(x + 2) - (2*x - 5)*(x + 1)/(x + 2)^2 + 2*(x + 1)/(x + 2)

# %%
#61

# %%
t = var('t')

# %%
def h(t): return sec(t)/t

# %%
plot(h(t),(t,pi/2+0.1,3*pi/2-0.1),color='blue',legend_label='h(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def derh(t): return derivative(h(t))

# %%
derh(t)
# Out:
# sec(t)*tan(t)/t - sec(t)/t^2

# %%
def derivh(t): return sec(t)*tan(t)/t - sec(t)/t^2

# %%
derivh(pi)
# Out:
# pi^(-2)

# %%
#67

# %%
def f(x): return tan(x)

# %%
def tangent(x): return 2*x + (2-pi)/2

# %%
p=[]

# %%
p.append(plot(f(x),(x,0,pi/2-0.1),color='blue',legend_label='f(x)'))

# %%
p.append(plot(tangent(x),(x,0,pi/2-0.1),color='red',legend_label='tangent line to f(x) at x=pi/4'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def der(x): return derivative(f(x)) 
print(der(x))
# Out:
# tan(x)^2 + 1

# %%
#89

# %%
t = var('t')

# %%
def h(t): return 112.43*t + 1332.38

# %%
plot(h(t),(t,0,10),color='blue',legend_label='h(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def p(t): return 2.857*t + 281.762

# %%
plot(p(t),(t,0,10),color='blue',legend_label='p(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def A(t): return h(t)/p(t)

# %%
A(t)
# Out:
# (112.430000000000*t + 1332.38000000000)/(2.85700000000000*t + 281.762000000000)

# %%
plot(A(t),(t,0,10),color='blue',legend_label='A(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def derA(t): return derivative(A(t))
print(derA(t))
# Out:
# -2.85700000000000*(112.430000000000*t + 1332.38000000000)/(2.85700000000000*t + 281.762000000000)^2 + 112.430000000000/(2.85700000000000*t + 281.762000000000)

# %%
plot(derA(t),(t,0,10),color='blue',legend_label='derA(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#117

# %%
t = var('t')

# %%
def s(t): return -8.25*t^2 + 66*t

# %%
def v(t): return derivative(s(t))
v(t)
# Out:
# -16.5000000000000*t + 66

# %%
def vel(t): return -16.5000000000000*t + 66

# %%
def a(t): return derivative(v(t))
a(t)
# Out:
# -16.5000000000000

# %%
def acc(t): return -16.5

# %%
import numpy

# %%
time_arr = numpy.array([0,1,2,3,4])
time_arr
# Out:
# array([0, 1, 2, 3, 4])

# %%
s(time_arr)
# Out:
# array([  0.  ,  57.75,  99.  , 123.75, 132.  ])

# %%
vel(time_arr)
# Out:
# array([66. , 49.5, 33. , 16.5,  0. ])

# %%
acc(time_arr)
# Out:
# -16.5000000000000

# %%
i_prev = 0
avg_vel_arr = numpy.empty(0)

for i in range(1,5):
    avg_vel = (s(i) - s(i_prev)) / (i - i_prev)
    avg_vel_arr = numpy.append(avg_vel_arr, avg_vel)
    i_prev = i

print(avg_vel_arr)
# Out:
# [57.75 41.25 24.75  8.25]
