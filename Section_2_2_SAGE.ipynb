# %%
#31

# %%
def f(x): return 8/x^2

# %%
plot(f(x),(x,-2,6),ymin=0,ymax=20,color='blue',legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def der(x): return derivative(f(x))

# %%
der(x)
# Out:
# -16/x^3

# %%
def deriv(x): return -16/x^3

# %%
deriv(2)
# Out:
# -2

# %%
#37

# %%
th=var('th')

# %%
def f1(th): return 4*sin(th) - th

# %%
plot(f1(th),(th,-3,3),color='blue',legend_label='f1(th)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def der1(th): return(derivative(f1(th)))

# %%
der1(th)
# Out:
# 4*cos(th) - 1

# %%
def deriv1(th): return 4*cos(th) - 1

# %%
deriv1(0)
# Out:
# 3

# %%
#55

# %%
def f2(x): return 2/x^(3/4)

# %%
def tan2(x): return (-3/2)*x + (7/2)

# %%
p=[]

# %%
p.append(plot(f2(x),(x,0.01,3),ymin=0,ymax=20,color='blue',legend_label='f2(x)'))

# %%
p.append(plot(tan2(x),(x,0.01,3),ymin=0,ymax=20,color='red',legend_label='tangent line at x=1'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def der2(x): return derivative(f2(x))

# %%
der2(x)
# Out:
# -3/2/x^(7/4)

# %%
def deriv2(x): return -3/2/x^(7/4)

# %%
deriv2(1)
# Out:
# -3/2

# %%
#85

# %%
def f3(x): return x^(3/2)

# %%
plot(f3(x),(x,0,8),color='blue',legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f3(x),(x,2,6),color='blue',legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f3(x),(x,3,5),color='blue',legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f3(x),(x,3.5,4.5),color='blue',legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f3(x),(x,3.9,4.1),color='blue',legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f3(4.01)
# Out:
# 8.03001874219481

# %%
mSec=(8.03001874-8)/(4.01-4)

# %%
mSec
# Out:
# 3.00187399999998

# %%
def der3(x): return derivative(f3(x))

# %%
der3(x)
# Out:
# 3/2*sqrt(x)

# %%
def deriv3(x): return 3/2*sqrt(x)

# %%
deriv3(4)
# Out:
# 3

# %%
def T3(x): return 3*x - 4

# %%
p3=[]

# %%
p3.append(plot(f3(x),(x,2,6),color='blue',legend_label='f3(x)'))

# %%
p3.append(plot(T3(x),(x,2,6),color='red',legend_label='T3(x)'))

# %%
sum(p3)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
import numpy

# %%
delx = numpy.array([-3.0,-2.0,-1.0,-0.5,-0.1,0.0,0.1,0.5,1.0,2.0,3.0])

# %%
delx
# Out:
# array([-3. , -2. , -1. , -0.5, -0.1,  0. ,  0.1,  0.5,  1. ,  2. ,  3. ])

# %%
f3(delx+4)
# Out:
# array([ 1.        ,  2.82842712,  5.19615242,  6.54790043,  7.70188289,
#         8.        ,  8.30186726,  9.54594155, 11.18033989, 14.69693846,
#        18.52025918])

# %%
T3(delx+4)
# Out:
# array([-1. ,  2. ,  5. ,  6.5,  7.7,  8. ,  8.3,  9.5, 11. , 14. , 17. ])

# %%
#107

# %%
v = var('v')

# %%
def R4(v): return 0.417*v - 0.020

# %%
def B4(v): return 5.571e-3*v^2 + 1.429e-3*v + 4.000e-2

# %%
def T4(v): return 5.571e-3*v^2 + 0.418429*v+ 0.020

# %%
p4=[]

# %%
p4.append(plot(R4(v),(v,20,100),color='blue',legend_label='R4(v)'))

# %%
p4.append(plot(B4(v),(v,20,100),color='red',legend_label='B4(v)'))

# %%
p4.append(plot(T4(v),(v,20,100),color='green',legend_label='T4(v)'))

# %%
sum(p4)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
def der4(v): return derivative(T4(v))

# %%
der4(v)
# Out:
# 0.0111420000000000*v + 0.418429000000000

# %%
def deriv4(v): return 0.0111420000000000*v + 0.418429000000000

# %%
deriv4(40)
# Out:
# 0.864109000000000

# %%
deriv4(80)
# Out:
# 1.30978900000000

# %%
deriv4(100)
# Out:
# 1.53262900000000

# %%
#117

# %%
def f5(x): return abs(sin(x))

# %%
plot(f5(x),(x,-3*pi,3*pi),color='blue',legend_label='f5(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def f6(x): return sin(abs(x))

# %%
plot(f6(x),(x,-3*pi,3*pi),color='blue',legend_label='f6(x)')
# Out:
# Graphics object consisting of 1 graphics primitive
